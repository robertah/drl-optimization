# %% [markdown]
# # Genetic Algorithm - Agents Analysis

# %%
# %matplotlib notebook  
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "src/"))

# %%
import numpy as np
import utils
import visualization

# %%
import importlib
importlib.reload(visualization)
import glob 
import os

# %% [markdown]
# ### Noise 0.1

# %%
list_of_files = glob.glob('/Users/fdangelo/Desktop/DeepLearning project/deep-learning/results/scores/*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
scores = np.load(latest_file)
#scores = utils.get_results()
#scores = np.load('/Users/fdangelo/Desktop/DeepLearning project/deep-learning/results/scores/BipedalWalker-v2-20190107143956.npy')

# %%
visualization.plot_scores(scores[0:300])
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
weights_hidden = np.empty((len(weights), len(weights[0]), weights[0][0][0].shape[0]*weights[0][0][0].shape[1]))
for i, w in enumerate(weights):
    for j, ww in enumerate(w):
        weights_hidden[i][j] = ww[0].reshape(-1)

# %%
visualization.plot_weights_2d(weights_hidden, scores, "Weights Evolution - noise: 0.1")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Noise 0.5

# %%
weights, scores = utils.get_results('20181228193346')

# %%
visualization.plot_scores(scores)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
weights_hidden = np.empty((len(weights), len(weights[0]), weights[0][0][0].shape[0]*weights[0][0][0].shape[1]))
for i, w in enumerate(weights):
    for j, ww in enumerate(w):
        weights_hidden[i][j] = ww[0].reshape(-1)

# %%
visualization.plot_weights_2d(weights_hidden, scores, "Weights Evolution - noise: 0.5")
# Out:
# <img src="data:image/png;base64,..." width="800">
