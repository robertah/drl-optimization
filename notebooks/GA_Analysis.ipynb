# %% [markdown]
# # Genetic Algorithm - Agents Analysis

# %%
# %matplotlib inline  
# USE %matplotlib notebook for animated plots 
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "src/"))

# %%
import numpy as np
import utils
import visualization

# %%
import importlib
importlib.reload(visualization)
# Out:
# <module 'visualization' from '/Users/roberta/Google Drive/Edu/ETH Zurich/3 - Deep Learning/Project/deep-learning/notebooks/../src/visualization.py'>

# %% [markdown]
# ### Noise 0.1

# %%
weights, scores = utils.get_results('20181228171611')

# %%
visualization.plot_scores(scores)

# %%
weights_hidden = np.empty((len(weights), len(weights[0]), weights[0][0][0].shape[0]*weights[0][0][0].shape[1]))
for i, w in enumerate(weights):
    for j, ww in enumerate(w):
        weights_hidden[i][j] = ww[0].reshape(-1)

# %%
visualization.plot_weights_2d(weights_hidden, scores, "Weights Evolution - noise: 0.1")

# %% [markdown]
# ### Noise 0.5

# %%
weights, scores = utils.get_results('20181228193346')

# %%
visualization.plot_scores(scores)

# %%
weights_hidden = np.empty((len(weights), len(weights[0]), weights[0][0][0].shape[0]*weights[0][0][0].shape[1]))
for i, w in enumerate(weights):
    for j, ww in enumerate(w):
        weights_hidden[i][j] = ww[0].reshape(-1)

# %%
visualization.plot_weights_2d(weights_hidden, scores, "Weights Evolution - noise: 0.5")

# %% [markdown]
# ### Noise 0.8

# %%
weights, scores = utils.get_results('20190103183514')

# %%
visualization.plot_scores(scores)

# %%
weights_hidden = np.empty((len(weights), len(weights[0]), weights[0][0][0].shape[0]*weights[0][0][0].shape[1]))
for i, w in enumerate(weights):
    for j, ww in enumerate(w):
        weights_hidden[i][j] = ww[0].reshape(-1)

# %%
visualization.plot_weights_2d(weights_hidden, scores, "Weights Evolution - noise: 0.8")
