# %% [markdown]
# # Genetic Agents Score Analysis

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "src/"))

# %%
import genetic
import visualization

# %%
import importlib
importlib.reload(genetic)
importlib.reload(visualization)
# Out:
# <module 'visualization' from '/Users/roberta/Desktop/deep-learning/notebooks/../src/visualization.py'>

# %% [markdown]
# ### 1. Run agents

# %%
# %%time
results = genetic.run_agent_genetic_2(n_generations=100)
# Out:
# CPU times: user 1h 3min 27s, sys: 4min 11s, total: 1h 7min 39s
# Wall time: 48min 27s

# %% [markdown]
# ### 2. Visualization of scores over generations

# %%
scores = np.array(results[:, 1, :], dtype=float)

# %%
visualization.plot_scores(scores)
