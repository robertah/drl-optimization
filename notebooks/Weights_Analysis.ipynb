# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "src/"))

# %%
import genetic
import visualization
# Out:
# Using TensorFlow backend.
# /Users/roberta/miniconda3/envs/deep-learning/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
import importlib
importlib.reload(genetic)
importlib.reload(visualization)
# Out:
# <module 'visualization' from '/Users/roberta/Desktop/deep-learning/notebooks/../src/visualization.py'>

# %%
# %%time
results, children = genetic.run_agent_genetic_2(n_generations=50, return_children=True)
# Out:
# CPU times: user 13min 53s, sys: 1min 5s, total: 14min 58s
# Wall time: 9min 53s

# %%
visualization.plot_weights_mean(weights=children[:, 0])

# %%
visualization.plot_weights_mean(weights=children[:, 2])
