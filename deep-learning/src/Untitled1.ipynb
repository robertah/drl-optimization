# %%
# %matplotlib inline  
# USE %matplotlib notebook for animated plots 
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "src/"))
import numpy as np
import utils
import visualization

# %%
import importlib
importlib.reload(visualization)
# Out:
# <module 'visualization' from '/Users/fdangelo/Desktop/DeepLearning project/deep-learning/src/../src/visualization.py'>

# %%
scores = np.load('/Users/fdangelo/Desktop/DeepLearning project/deep-learning/results/scores/BipedalWalker-v2-20190104180006.npy')

# %%
visualization.plot_scores(scores)
