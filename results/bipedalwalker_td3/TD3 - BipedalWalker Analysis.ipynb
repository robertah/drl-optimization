# %% [markdown]
# ## TD3 - BipedalWalker Analysis

# %%
# %matplotlib inline

# %%
import numpy as np
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "../src/"))

# %%
import visualization
import loss_analysis
# Out:
# /Users/roberta/miniconda3/envs/deep-learning/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Using TensorFlow backend.

# %%
import importlib
importlib.reload(visualization)
importlib.reload(loss_analysis)
# Out:
# <module 'loss_analysis' from '/Users/roberta/Desktop/deep-learning/results/bipedalwalker_td3/../../src/loss_analysis.py'>

# %%
timestamp = '20190118192711'

# %%
name = 'BipedalWalker TD3 - '

# %% [markdown]
# ### Scores

# %%
scores = np.load('../training/td3/BipedalWalker-v2-' + timestamp + '/results.npy')

# %%
visualization.plot_scores_episodes(scores, title=name + 'scores')

# %% [markdown]
# ### Distances between and within clusters

# %%
distances = np.load('../training/td3/BipedalWalker-v2-' + timestamp + '/distances.npy')

# %%
visualization.plot_distances(distances[0][0], distances[1][0], x_label="Episode", title=name + "Distances - First Hidden Layer", file='distances_1.png')

# %%
visualization.plot_distances(distances[0][1], distances[1][1], x_label="Episode", title=name + "Distances - Second Hidden Layer", file='distances_2.png')
