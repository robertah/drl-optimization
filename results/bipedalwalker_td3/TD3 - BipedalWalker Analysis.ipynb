# %% [markdown]
# ## TD3 - BipedalWalker Analysis

# %%
# %matplotlib inline

# %%
import numpy as np
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), os.pardir, "../src/"))

# %%
timestamp = '20190118192711'

# %% [markdown]
# ### 1. Convergence speed

# %% [markdown]
# ### 4. Distances between and within clusters

# %%
distances = np.load('../training/td3/BipedalWalker-v2-' + timestamp + '/distances.npy')

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['figure.figsize'] = [12, 8]

# %%
font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 16}
matplotlib.rc('font', **font)

# %%
plt.title("Distances - First Hidden Layer")
plt.plot(distances[0][0], label='Between consecutive')
plt.plot(distances[1][0], label='From initial')
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Euclidean distance')
plt.savefig('distances_1.pdf')

# %%
plt.title("Distances - Second Hidden Layer")
plt.plot(distances[0][1], label='Between consecutive')
plt.plot(distances[1][1], label='From initial')
plt.legend()
plt.xlabel('Episodes')
plt.ylabel('Euclidean distance')
plt.savefig('distances_2.pdf')
