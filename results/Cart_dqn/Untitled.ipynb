# %%
import numpy as np

# %%
#scores = np.load('Cart_genetic/score_500/serio/scores.npy')
weights = np.load('Cart_genetic/score_500/serio/CartPole-v1-20190119010914.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-0d3151b8e38a> in <module>
#       1 #scores = np.load('Cart_genetic/score_500/serio/scores.npy')
# ----> 2 weights = np.load('Cart_genetic/score_500/serio/CartPole-v1-20190119010914.npy')
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     382     own_fid = False
#     383     if isinstance(file, basestring):
# --> 384         fid = open(file, "rb")
#     385         own_fid = True
#     386     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cart_genetic/score_500/serio/CartPole-v1-20190119010914.npy'

# %%
print(scores)
# Out:
# [[  0   0   0]
#  [ 15  10  10]
#  [ 10  10  11]
#  [  9  10  10]
#  [  9  10   9]
#  [  9   9   9]
#  [ 10   9   9]
#  [ 10   9  10]
#  [  9   8   9]
#  [ 10   9   9]
#  [  9  10   8]
#  [ 10  10  11]
#  [  9  10   9]
#  [ 10   9  11]
#  [  8   8  10]
#  [  9   9   8]
#  [ 10   8  10]
#  [ 10   8  10]
#  [  9   9  10]
#  [ 10  10   8]
#  [  9   9   8]
#  [ 10  10   9]
#  [  9  10  10]
#  [  9  11  10]
#  [  8  10   9]
#  [  9  10   9]
#  [ 11  10  10]
#  [ 11   9   9]
#  [  9   9  10]
#  [ 10   9  10]
#  [  9  10  10]
#  [ 10  10   9]
#  [  9  10  10]
#  [ 10  10   9]
#  [  9   9  10]
#  [ 10  10   9]
#  [  8  10   9]
#  [  9   9   9]
#  [  9  10   9]
#  [  9   8  11]
#  [ 15  14  14]
#  [ 16  22  16]
#  [ 29  21  32]
#  [ 59 134  58]
#  [ 27  33  25]
#  [ 64  58  99]
#  [ 34  50  35]
#  [ 30  29  33]
#  [ 22  16  19]
#  [ 17  27  17]
#  [ 25  19  21]
#  [ 31  21  40]
#  [ 21  20  25]
#  [ 23  30  23]
#  [ 22  25  23]
#  [ 25  25  33]
#  [ 26  31  23]
#  [ 30  32  26]
# ...

# %%
weights.shape
# Out:
# (35297, 4)

# %%
best_agent = weights[35296]

# %%
np.save('score_500/serio/best_agent_dqn.npy', best_agent)
